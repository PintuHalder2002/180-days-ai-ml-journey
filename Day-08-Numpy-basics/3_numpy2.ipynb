# %%
import numpy as np

# %%
rev_q1 = np.array([10, 12, 9])
rev_q1.ndim
# Out:
# 1

# %%
rev = np.array([[10, 12, 9],[15, 11, 13]])
rev.ndim
# Out:
# 2

# %%
rev
# Out:
# array([[10, 12,  9],
#        [15, 11, 13]])

# %%
print(rev[1,0])
# Out:
# 15

# %%
rev[1,0] = 14
rev
# Out:
# array([[10, 12,  9],
#        [14, 11, 13]])

# %%
rev.dtype
# Out:
# dtype('int64')

# %%
rev = np.array([[10, 12, 9], [15, 11, 13]], dtype = np.float64)

rev.dtype   # float 64 means each of the element is occupying 64 bits in meomory.
# Out:
# dtype('float64')

# %%
rev.itemsize # each of the element occupy 8 byte in memory.
# Out:
# 8

# %%
rev.size # total number of elements = 6
# Out:
# 6

# %%
rev.shape
# Out:
# (2, 3)

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
np.sort(rev)
# Out:
# array([[ 9., 10., 12.],
#        [11., 13., 15.]])

# %%
np.sort(rev, axis = None)
# Out:
# array([ 9., 10., 11., 12., 13., 15.])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(20, 30, 2)
# Out:
# array([20, 22, 24, 26, 28])

# %%
np.linspace(10, 20, 20)
# Out:
# array([10.        , 10.52631579, 11.05263158, 11.57894737, 12.10526316,
#        12.63157895, 13.15789474, 13.68421053, 14.21052632, 14.73684211,
#        15.26315789, 15.78947368, 16.31578947, 16.84210526, 17.36842105,
#        17.89473684, 18.42105263, 18.94736842, 19.47368421, 20.        ])

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
rev.flatten()
# Out:
# array([10., 12.,  9., 15., 11., 13.])

# %%
rev.reshape(3, 2)
# Out:
# array([[10., 12.],
#        [ 9., 15.],
#        [11., 13.]])

# %%
rev.reshape(6,1)
# Out:
# array([[10.],
#        [12.],
#        [ 9.],
#        [15.],
#        [11.],
#        [13.]])

# %%
rev.min()
# Out:
# np.float64(9.0)

# %%
rev.max()
# Out:
# np.float64(15.0)

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
rev.sum(axis = 1) # horizontal sum
# Out:
# array([31., 39.])

# %%
rev.sum(axis = 0) # vertical sum
# Out:
# array([25., 23., 22.])

# %%
b = np.array([1,4,16])

# %%
np.sqrt(b)
# Out:
# array([1., 2., 4.])
