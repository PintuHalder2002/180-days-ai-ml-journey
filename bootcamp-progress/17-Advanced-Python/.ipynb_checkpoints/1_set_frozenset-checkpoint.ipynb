# %%
print(list(range(8)))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
myset = set([1,2,3,2,3,4,4,5])

myset
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Set does not give duplicate values , all values are unique.

# %%
list(myset)
# Out:
# [1, 2, 3, 4, 5]

# %%
myset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myset[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# - TypeError: 'set' object is not subscriptable.
# - that means set has no order or indexing.

# %%
menu = set(['Dosa' , 'Idli' , 'Biriyani'])
menu
# Out:
# {'Biriyani', 'Dosa', 'Idli'}

# %%
menu.add("Pizza")
menu
# Out:
# {'Biriyani', 'Dosa', 'Idli', 'Pizza'}

# %%
menu.add("Pizza")

# %%
menu
# Out:
# {'Biriyani', 'Dosa', 'Idli', 'Pizza'}

# %%
menu.remove("Dosa")

# %%
menu
# Out:
# {'Biriyani', 'Idli', 'Pizza'}

# %% [markdown]
# # frozenset()

# %%
menu = frozenset(["Biriyani" , "Dosa" , "Idli"])

menu
# Out:
# frozenset({'Biriyani', 'Dosa', 'Idli'})

# %%
menu.add("Pizza")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 menu.add("Pizza")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# - 'frozenset' object has no attribute 'add'

# %%
"Dosa" in menu
# Out:
# True

# %%
"Burger" in menu
# Out:
# False

# %%
transactions = [
    {'customer_name': "Mira" , "amount": 56 , "date": "2024-08-01"},
    {'customer_name': "Mira" , "amount": 12.3 , "date": "2024-09-05"},
    {'customer_name': "Mohan" , "amount": 21 , "date": "2024-09-03"},
    {'customer_name': "Mohan" , "amount": 36.8 , "date": "2024-09-10"},
    {'customer_name': "Lucy" , "amount": 66.3 , "date": "2024-09-10"}
]

# %%
type(transactions)
# Out:
# list

# %%
customers = set()

for trans in transactions:
    customers.add(trans['customer_name'])

customers
# Out:
# {'Lucy', 'Mira', 'Mohan'}

# %%
customers_list = list(customers)

# %%
a = {"Mira" , 'Mohan' , 'Luci'  'Ahmed'}
b = {'chen' , 'Mohan' , 'Radha' , 'Maria'}

# %%
a & b  # intersection
# Out:
# {'Mohan'}

# %%
a.intersection(b)
# Out:
# {'Mohan'}

# %%
a | b # union
# Out:
# {'LuciAhmed', 'Maria', 'Mira', 'Mohan', 'Radha', 'chen'}

# %%
a.union(b)
# Out:
# {'LuciAhmed', 'Maria', 'Mira', 'Mohan', 'Radha', 'chen'}

# %%
a - b
# Out:
# {'LuciAhmed', 'Mira'}

# %%
a - (a.intersection(b))
# Out:
# {'LuciAhmed', 'Mira'}

# %%
a - b == a - (a & b)
# Out:
# True
